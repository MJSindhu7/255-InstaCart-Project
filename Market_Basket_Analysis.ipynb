# %% [markdown]
# Market Basket Analysis

# %% [markdown]
# Association Analysis

# %% [markdown]
# Get our pandas and MLxtend code imported and read the data:

# %%
#importsimport sys
# !{sys.executable} -m pip install mlxtend
import pandas as pd #Python data analysis library
import numpy as np #Python scientific computing
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# Citation - “The Instacart Online Grocery Shopping Dataset 2017”, Accessed from https://www.instacart.com/datasets/grocery-shopping-2017"

# %%
#import dataset
trainDf = pd.read_csv("order_products__train.csv")
orderDf = pd.read_csv("orders.csv")
productDf = pd.read_csv("products.csv")

# %% [markdown]
# We will merge the prior and train dataset to get the complete order dataset. We will use append() for doing so.

# %%
priorDf = pd.read_csv("order_products__prior.csv")
trainDf = trainDf.append(priorDf,ignore_index = True)

# %% [markdown]
# For counting each product, we can assign reordered column as 1

# %%
trainDf['reordered'] = 1

# %%
productCountDf = trainDf.groupby("product_id",as_index = False)["order_id"].count()

# %%
newproductCountDf=productCountDf.merge(productDf, left_on='product_id', right_on='product_id', how='inner')
newDf = newproductCountDf[['product_id','product_name']]
newDf
# Out:
#        product_id                                       product_name
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# 5               6                                       Dry Nose Oil
# 6               7                     Pure Coconut Water With Orange
# 7               8                  Cut Russet Potatoes Steam N' Mash
# 8               9                  Light Strawberry Blueberry Yogurt
# 9              10     Sparkling Orange Juice & Prickly Pear Beverage
# 10             11                                  Peach Mango Juice
# 11             12                         Chocolate Fudge Layer Cake
# 12             13                                  Saline Nasal Mist
# 13             14                     Fresh Scent Dishwasher Cleaner
# 14             15                           Overnight Diapers Size 6
# 15             16                      Mint Chocolate Flavored Syrup
# 16             17                                  Rendered Duck Fat
# 17             18                Pizza for One Suprema  Frozen Pizza
# 18             19   Gluten Free Quinoa Three Cheese & Mushroom Blend
# 19             20     Pomegranate Cranberry & Aloe Vera Enrich Drink
# 20             21                   Small & Medium Dental Dog Treats
# 21             22                  Fresh Breath Oral Rinse Mild Mint
# 22             23                             Organic Turkey Burgers
# 23             24  Tri-Vi-Sol® Vitamins A-C-and D Supplement Drop...
# 24             25            Salted Caramel Lean Protein & Fiber Bar
# 25             26        Fancy Feast Trout Feast Flaked Wet Cat Food
# 26             27  Complete Spring Water Foaming Antibacterial Ha...
# 27             28                                  Wheat Chex Cereal
# 28             29  Fresh Cut Golden Sweet No Salt Added Whole Ker...
# 29             30         Three Cheese Ziti, Marinara with Meatballs
# ...           ...                                                ...
# 49655       49659                            Organic Creamed Coconut
# 49656       49660                        Professionals Sleek Shampoo
# 49657       49661                                              Porto
# 49658       49662                       Bacon Cheddar Pretzel Pieces
# 49659       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
# 49660       49664                     Lemon Cayenne Drinking Vinegar
# 49661       49665      Super Dark Coconut Ash & Banana Chocolate Bar
# 49662       49666                      Ginger Snaps Snacking Cookies
# 49663       49667           Enchilada with Spanish Rice & Beans Meal
# 49664       49668                     Apple Cinnamon Scented Candles
# 49665       49669                                   K Cup Dark Blend
# 49666       49670                                Beef Summer Sausage
# 49667       49671                               Milk Chocolate Drops
# 49668       49672                             Cafe Mocha K-Cup Packs
# 49669       49673              Stone Baked Multi Grain Artisan Rolls
# 49670       49674            Frozen Greek Yogurt Bars Chocolate Chip
# 49671       49675                Cinnamon Dolce Keurig Brewed K Cups
# 49672       49676                             Ultra Red Energy Drink
# 49673       49677                    Thick & Chunky Sloppy Joe Sauce
# 49674       49678                    Large Chicken & Cheese Taquitos
# 49675       49679                            Famous Chocolate Wafers
# 49676       49680                 All Natural Creamy Caesar Dressing
# 49677       49681            Spaghetti with Meatballs and Sauce Meal
# 49678       49682                                 California Limeade
# 49679       49683                                     Cucumber Kirby
# 49680       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49681       49685                 En Croute Roast Hazelnut Cranberry
# 49682       49686                                   Artisan Baguette
# 49683       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49684       49688                             Fresh Foaming Cleanser
#
# [49685 rows x 2 columns]

# %%
#Top 100 most frequently purchased products
topLev = 100
productCountDf = productCountDf.sort_values("order_id",ascending = False)
topProdFrame = productCountDf.iloc[0:topLev,:]
productId= topProdFrame.loc[:,["product_id"]]
productId
# Out:
#        product_id
# 24849       24852
# 13173       13176
# 21134       21137
# 21900       21903
# 47205       47209
# 47762       47766
# 47622       47626
# 16794       16797
# 26206       26209
# 27842       27845
# 27963       27966
# 22932       22935
# 24961       24964
# 45004       45007
# 39272       39275
# 49679       49683
# 28201       28204
# 5874         5876
# 40703       40706
# 8274         8277
# 4918         4920
# 30388       30391
# 45063       45066
# 42262       42265
# 44629       44632
# 49231       49235
# 19054       19057
# 4603         4605
# 21613       21616
# 37643       37646
# ...           ...
# 8171         8174
# 44139       44142
# 20111       20114
# 27341       27344
# 11517       11520
# 29484       29487
# 18462       18465
# 28196       28199
# 15287       15290
# 46902       46906
# 9836         9839
# 27153       27156
# 3955         3957
# 43119       43122
# 23906       23909
# 34355       34358
# 4797         4799
# 9384         9387
# 16756       16759
# 195           196
# 42733       42736
# 4208         4210
# 38686       38689
# 41784       41787
# 47140       47144
# 41217       41220
# 7778         7781
# 32997       33000
# 20992       20995
# 21706       21709
#
# [100 rows x 1 columns]

# %% [markdown]
# # Now we will filter the orders and get orders containting the the most   frequently purchased products

# %%
df = trainDf[0:0]
for i in range(0,99):
    pId = productId.iloc[i]['product_id'] 
    stDf = trainDf[trainDf.product_id == pId ]
    df = df.append(stDf,ignore_index = False)

# %%
df.head()
# Out:
#      order_id  product_id  add_to_cart_order  reordered
# 115       226       24852                  2          1
# 156       473       24852                  2          1
# 196       878       24852                  2          1
# 272      1042       24852                  1          1
# 297      1139       24852                  1          1

# %% [markdown]
# Now we need to consolidate the items into 1 transaction per row with each product 1 hot encoded. Each row will represent an order and each column will represent product_id. If the cell value is '1' say (i,j) then ith order contains jth product.

# %%
df=df.merge(newDf, left_on='product_id', right_on='product_id', how='inner')
df=df[['order_id','add_to_cart_order','reordered','product_name']]
df
# Out:
#          order_id  add_to_cart_order  reordered              product_name
# 0             226                  2          1                    Banana
# 1             473                  2          1                    Banana
# 2             878                  2          1                    Banana
# 3            1042                  1          1                    Banana
# 4            1139                  1          1                    Banana
# 5            1145                  1          1                    Banana
# 6            1468                  1          1                    Banana
# 7            1572                  3          1                    Banana
# 8            1591                 19          1                    Banana
# 9            2068                  1          1                    Banana
# 10           2415                  2          1                    Banana
# 11           2937                  1          1                    Banana
# 12           3056                  9          1                    Banana
# 13           3209                  2          1                    Banana
# 14           3243                  4          1                    Banana
# 15           3378                  9          1                    Banana
# 16           3740                  6          1                    Banana
# 17           3898                  3          1                    Banana
# 18           3957                  8          1                    Banana
# 19           4164                 13          1                    Banana
# 20           4284                  3          1                    Banana
# 21           4340                  1          1                    Banana
# 22           4431                  1          1                    Banana
# 23           4556                  1          1                    Banana
# 24           4562                  2          1                    Banana
# 25           4827                  2          1                    Banana
# 26           4918                  1          1                    Banana
# 27           4968                 13          1                    Banana
# 28           5447                 17          1                    Banana
# 29           5739                  4          1                    Banana
# ...           ...                ...        ...                       ...
# 7761230   3417348                  9          1  Organic Broccoli Florets
# 7761231   3417358                  1          1  Organic Broccoli Florets
# 7761232   3418009                 15          1  Organic Broccoli Florets
# 7761233   3418216                 30          1  Organic Broccoli Florets
# 7761234   3418250                 14          1  Organic Broccoli Florets
# 7761235   3418265                 15          1  Organic Broccoli Florets
# 7761236   3418483                 25          1  Organic Broccoli Florets
# 7761237   3418488                  3          1  Organic Broccoli Florets
# 7761238   3418602                  4          1  Organic Broccoli Florets
# 7761239   3418640                 14          1  Organic Broccoli Florets
# 7761240   3418695                  2          1  Organic Broccoli Florets
# 7761241   3418741                  3          1  Organic Broccoli Florets
# 7761242   3418781                  5          1  Organic Broccoli Florets
# 7761243   3418795                  6          1  Organic Broccoli Florets
# 7761244   3418840                  5          1  Organic Broccoli Florets
# 7761245   3419159                 16          1  Organic Broccoli Florets
# 7761246   3419417                  5          1  Organic Broccoli Florets
# 7761247   3419440                 15          1  Organic Broccoli Florets
# 7761248   3419547                 12          1  Organic Broccoli Florets
# 7761249   3419857                  3          1  Organic Broccoli Florets
# 7761250   3419873                  3          1  Organic Broccoli Florets
# 7761251   3419980                  2          1  Organic Broccoli Florets
# 7761252   3420043                  1          1  Organic Broccoli Florets
# 7761253   3420142                 16          1  Organic Broccoli Florets
# 7761254   3420310                 10          1  Organic Broccoli Florets
# 7761255   3420522                  1          1  Organic Broccoli Florets
# 7761256   3420704                  5          1  Organic Broccoli Florets
# 7761257   3420826                  4          1  Organic Broccoli Florets
# 7761258   3420932                 15          1  Organic Broccoli Florets
# 7761259   3421011                  3          1  Organic Broccoli Florets
#
# [7761260 rows x 4 columns]

# %%
basket = df.groupby(['order_id', 'product_name'])['reordered'].sum().unstack().reset_index().fillna(0).set_index('order_id')

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

# %%
basket_sets = basket.applymap(encode_units)

# %%
basket_sets.head()
# Out:
# product_name  100% Raw Coconut Water  100% Whole Wheat Bread  \
# order_id
# 1                                  0                       0
# 2                                  0                       0
# 3                                  0                       0
# 5                                  0                       0
# 9                                  0                       0
#
# product_name  2% Reduced Fat Milk  Apple Honeycrisp Organic  Asparagus  \
# order_id
# 1                               0                         0          0
# 2                               0                         0          0
# 3                               0                         0          0
# 5                               1                         0          0
# 9                               0                         0          0
#
# product_name  Bag of Organic Bananas  Banana  Bartlett Pears  Blueberries  \
# order_id
# 1                                  1       0               0            0
# 2                                  0       0               0            0
# 3                                  0       0               0            0
# 5                                  1       0               0            0
# 9                                  0       0               0            0
#
# product_name  Boneless Skinless Chicken Breasts  ...  \
# order_id                                         ...
# 1                                             0  ...
# 2                                             0  ...
# 3                                             0  ...
# 5                                             0  ...
# 9                                             0  ...
#
# product_name  Sparkling Natural Mineral Water  Sparkling Water Grapefruit  \
# order_id
# 1                                           0                           0
# 2                                           0                           0
# 3                                           0                           0
# 5                                           0                           0
# 9                                           0                           0
#
# product_name  Spring Water  Strawberries  Uncured Genoa Salami  \
# order_id
# 1                        0             0                     0
# 2                        0             0                     0
# 3                        0             0                     0
# 5                        0             0                     0
# 9                        0             0                     0
#
# product_name  Unsalted Butter  Unsweetened Almondmilk  \
# order_id
# 1                           0                       0
# 2                           0                       0
# 3                           0                       1
# 5                           0                       0
# 9                           0                       0
#
# product_name  Unsweetened Original Almond Breeze Almond Milk  Whole Milk  \
# order_id
# 1                                                          0           0
# 2                                                          0           0
# 3                                                          0           0
# 5                                                          0           0
# 9                                                          0           0
#
# product_name  Yellow Onions
# order_id
# 1                         0
# 2                         0
# 3                         0
# 5                         0
# 9                         0
#
# [5 rows x 99 columns]

# %%
basket_sets.size
# Out:
# 241667217

# %% [markdown]
# Now that the data is structured properly, we can generate frequent item sets that have a support of at least 1%

# %%
# Build up the frequent items
frequent_itemsets = apriori(basket_sets, min_support=0.01, use_colnames=True)

# %%
frequent_itemsets
# Out:
#       support                                        itemsets
# 0    0.016088                        (100% Raw Coconut Water)
# 1    0.025855                        (100% Whole Wheat Bread)
# 2    0.015825                           (2% Reduced Fat Milk)
# 3    0.035751                      (Apple Honeycrisp Organic)
# 4    0.029147                                     (Asparagus)
# 5    0.161785                        (Bag of Organic Bananas)
# 6    0.201259                                        (Banana)
# 7    0.015002                                (Bartlett Pears)
# 8    0.023870                                   (Blueberries)
# 9    0.021453             (Boneless Skinless Chicken Breasts)
# 10   0.018425                                (Broccoli Crown)
# 11   0.019438                              (Bunched Cilantro)
# 12   0.030820                                       (Carrots)
# 13   0.016920                              (Clementines, Bag)
# 14   0.040854                                (Cucumber Kirby)
# 15   0.021434                        (Extra Virgin Olive Oil)
# 16   0.030411                             (Fresh Cauliflower)
# 17   0.015787                                        (Garlic)
# 18   0.015389                           (Granny Smith Apples)
# 19   0.016590                    (Grape White/Green Seedless)
# 20   0.019226                               (Grated Parmesan)
# 21   0.023762                             (Green Bell Pepper)
# 22   0.029348                                   (Half & Half)
# 23   0.021506                                 (Hass Avocados)
# 24   0.034132                              (Honeycrisp Apple)
# 25   0.018213                              (Jalapeno Peppers)
# 26   0.017318                           (Large Alfresco Eggs)
# 27   0.065869                                   (Large Lemon)
# 28   0.019873                          (Lime Sparkling Water)
# 29   0.060080                                         (Limes)
# ..        ...                                             ...
# 98   0.031514                                 (Yellow Onions)
# 99   0.021551  (Organic Baby Spinach, Bag of Organic Bananas)
# 100  0.026530  (Organic Hass Avocado, Bag of Organic Bananas)
# 101  0.017321   (Organic Raspberries, Bag of Organic Bananas)
# 102  0.026505  (Bag of Organic Bananas, Organic Strawberries)
# 103  0.011306    (Bag of Organic Bananas, Organic Whole Milk)
# 104  0.010476  (Bag of Organic Bananas, Organic Yellow Onion)
# 105  0.013453                        (Banana, Cucumber Kirby)
# 106  0.012142                      (Honeycrisp Apple, Banana)
# 107  0.017631                           (Large Lemon, Banana)
# 108  0.013561                                 (Banana, Limes)
# 109  0.022781                       (Banana, Organic Avocado)
# 110  0.021873                  (Organic Baby Spinach, Banana)
# 111  0.014401                    (Banana, Organic Fuji Apple)
# 112  0.013178                  (Banana, Organic Hass Avocado)
# 113  0.023895                  (Banana, Organic Strawberries)
# 114  0.013390                    (Banana, Organic Whole Milk)
# 115  0.010551                   (Banana, Seedless Red Grapes)
# 116  0.017689                          (Banana, Strawberries)
# 117  0.011879                            (Large Lemon, Limes)
# 118  0.010555                  (Large Lemon, Organic Avocado)
# 119  0.013228         (Organic Baby Spinach, Organic Avocado)
# 120  0.010271         (Organic Avocado, Organic Strawberries)
# 121  0.014810    (Organic Baby Spinach, Organic Hass Avocado)
# 122  0.016293    (Organic Baby Spinach, Organic Strawberries)
# 123  0.010252     (Organic Blueberries, Organic Strawberries)
# 124  0.010984     (Organic Hass Avocado, Organic Raspberries)
# 125  0.017342    (Organic Hass Avocado, Organic Strawberries)
# 126  0.014556     (Organic Raspberries, Organic Strawberries)
# 127  0.010146      (Organic Strawberries, Organic Whole Milk)
#
# [128 rows x 2 columns]

# %% [markdown]
# # The final step is to generate the rules with their corresponding support, confidence and lift:

# %%
# Create the rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules
# Out:
#                  antecedents               consequents  antecedent support  \
# 0     (Organic Baby Spinach)  (Bag of Organic Bananas)            0.103112
# 1   (Bag of Organic Bananas)    (Organic Baby Spinach)            0.161785
# 2     (Organic Hass Avocado)  (Bag of Organic Bananas)            0.090483
# 3   (Bag of Organic Bananas)    (Organic Hass Avocado)            0.161785
# 4      (Organic Raspberries)  (Bag of Organic Bananas)            0.058418
# 5   (Bag of Organic Bananas)     (Organic Raspberries)            0.161785
# 6   (Bag of Organic Bananas)    (Organic Strawberries)            0.161785
# 7     (Organic Strawberries)  (Bag of Organic Bananas)            0.112891
# 8   (Bag of Organic Bananas)      (Organic Whole Milk)            0.161785
# 9       (Organic Whole Milk)  (Bag of Organic Bananas)            0.058504
# 10  (Bag of Organic Bananas)    (Organic Yellow Onion)            0.161785
# 11    (Organic Yellow Onion)  (Bag of Organic Bananas)            0.048223
# 12                  (Banana)          (Cucumber Kirby)            0.201259
# 13          (Cucumber Kirby)                  (Banana)            0.040854
# 14        (Honeycrisp Apple)                  (Banana)            0.034132
# 15                  (Banana)        (Honeycrisp Apple)            0.201259
# 16             (Large Lemon)                  (Banana)            0.065869
# 17                  (Banana)             (Large Lemon)            0.201259
# 18                  (Banana)                   (Limes)            0.201259
# 19                   (Limes)                  (Banana)            0.060080
# 20                  (Banana)         (Organic Avocado)            0.201259
# 21         (Organic Avocado)                  (Banana)            0.075468
# 22    (Organic Baby Spinach)                  (Banana)            0.103112
# 23                  (Banana)    (Organic Baby Spinach)            0.201259
# 24                  (Banana)      (Organic Fuji Apple)            0.201259
# 25      (Organic Fuji Apple)                  (Banana)            0.038052
# 26                  (Banana)    (Organic Strawberries)            0.201259
# 27    (Organic Strawberries)                  (Banana)            0.112891
# 28                  (Banana)      (Organic Whole Milk)            0.201259
# 29      (Organic Whole Milk)                  (Banana)            0.058504
# 30                  (Banana)     (Seedless Red Grapes)            0.201259
# 31     (Seedless Red Grapes)                  (Banana)            0.035537
# 32                  (Banana)            (Strawberries)            0.201259
# 33            (Strawberries)                  (Banana)            0.061221
# 34             (Large Lemon)                   (Limes)            0.065869
# 35                   (Limes)             (Large Lemon)            0.060080
# 36             (Large Lemon)         (Organic Avocado)            0.065869
# 37         (Organic Avocado)             (Large Lemon)            0.075468
# 38    (Organic Baby Spinach)         (Organic Avocado)            0.103112
# 39         (Organic Avocado)    (Organic Baby Spinach)            0.075468
# 40         (Organic Avocado)    (Organic Strawberries)            0.075468
# 41    (Organic Strawberries)         (Organic Avocado)            0.112891
# 42    (Organic Baby Spinach)    (Organic Hass Avocado)            0.103112
# 43    (Organic Hass Avocado)    (Organic Baby Spinach)            0.090483
# 44    (Organic Baby Spinach)    (Organic Strawberries)            0.103112
# 45    (Organic Strawberries)    (Organic Baby Spinach)            0.112891
# 46     (Organic Blueberries)    (Organic Strawberries)            0.043024
# 47    (Organic Strawberries)     (Organic Blueberries)            0.112891
# 48    (Organic Hass Avocado)     (Organic Raspberries)            0.090483
# 49     (Organic Raspberries)    (Organic Hass Avocado)            0.058418
# 50    (Organic Hass Avocado)    (Organic Strawberries)            0.090483
# 51    (Organic Strawberries)    (Organic Hass Avocado)            0.112891
# 52     (Organic Raspberries)    (Organic Strawberries)            0.058418
# 53    (Organic Strawberries)     (Organic Raspberries)            0.112891
# 54    (Organic Strawberries)      (Organic Whole Milk)            0.112891
# 55      (Organic Whole Milk)    (Organic Strawberries)            0.058504
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.161785  0.021551    0.209007  1.291881  0.004869    1.059699
# 1             0.103112  0.021551    0.133208  1.291881  0.004869    1.034722
# 2             0.161785  0.026530    0.293199  1.812281  0.011891    1.185929
# 3             0.090483  0.026530    0.163981  1.812281  0.011891    1.087914
# 4             0.161785  0.017321    0.296508  1.832734  0.007870    1.191507
# 5             0.058418  0.017321    0.107065  1.832734  0.007870    1.054479
# 6             0.112891  0.026505    0.163832  1.451233  0.008241    1.060921
# 7             0.161785  0.026505    0.234787  1.451233  0.008241    1.095402
# 8             0.058504  0.011306    0.069883  1.194505  0.001841    1.012234
# 9             0.161785  0.011306    0.193253  1.194505  0.001841    1.039006
# 10            0.048223  0.010476    0.064756  1.342844  0.002675    1.017678
# 11            0.161785  0.010476    0.217252  1.342844  0.002675    1.070862
# 12            0.040854  0.013453    0.066844  1.636175  0.005231    1.027852
# 13            0.201259  0.013453    0.329296  1.636175  0.005231    1.190898
# 14            0.201259  0.012142    0.355725  1.767494  0.005272    1.239751
# 15            0.034132  0.012142    0.060329  1.767494  0.005272    1.027878
# 16            0.201259  0.017631    0.267663  1.329938  0.004374    1.090673
# 17            0.065869  0.017631    0.087602  1.329938  0.004374    1.023819
# 18            0.060080  0.013561    0.067380  1.121500  0.001469    1.007827
# 19            0.201259  0.013561    0.225713  1.121500  0.001469    1.031581
# 20            0.075468  0.022781    0.113194  1.499886  0.007593    1.042541
# 21            0.201259  0.022781    0.301866  1.499886  0.007593    1.144108
# 22            0.201259  0.021873    0.212133  1.054029  0.001121    1.013802
# 23            0.103112  0.021873    0.108683  1.054029  0.001121    1.006250
# 24            0.038052  0.014401    0.071552  1.880364  0.006742    1.036082
# 25            0.201259  0.014401    0.378441  1.880364  0.006742    1.285060
# 26            0.112891  0.023895    0.118728  1.051702  0.001175    1.006623
# 27            0.201259  0.023895    0.211665  1.051702  0.001175    1.013199
# 28            0.058504  0.013390    0.066529  1.137168  0.001615    1.008597
# 29            0.201259  0.013390    0.228866  1.137168  0.001615    1.035800
# 30            0.035537  0.010551    0.052425  1.475240  0.003399    1.017823
# 31            0.201259  0.010551    0.296906  1.475240  0.003399    1.136037
# 32            0.061221  0.017689    0.087891  1.435638  0.005368    1.029240
# 33            0.201259  0.017689    0.288936  1.435638  0.005368    1.123303
# 34            0.060080  0.011879    0.180345  3.001750  0.007922    1.146726
# 35            0.065869  0.011879    0.197723  3.001750  0.007922    1.164349
# 36            0.075468  0.010555    0.160244  2.123337  0.005584    1.100953
# 37            0.065869  0.010555    0.139862  2.123337  0.005584    1.086025
# 38            0.075468  0.013228    0.128289  1.699910  0.005446    1.060595
# 39            0.103112  0.013228    0.175281  1.699910  0.005446    1.087508
# 40            0.112891  0.010271    0.136095  1.205542  0.001751    1.026859
# 41            0.075468  0.010271    0.090980  1.205542  0.001751    1.017064
# 42            0.090483  0.014810    0.143632  1.587393  0.005480    1.062064
# 43            0.103112  0.014810    0.163679  1.587393  0.005480    1.072421
# 44            0.112891  0.016293    0.158014  1.399704  0.004653    1.053591
# 45            0.103112  0.016293    0.144326  1.399704  0.004653    1.048166
# 46            0.112891  0.010252    0.238274  2.110653  0.005395    1.164604
# 47            0.043024  0.010252    0.090809  2.110653  0.005395    1.052558
# 48            0.058418  0.010984    0.121389  2.077938  0.005698    1.071671
# 49            0.090483  0.010984    0.188018  2.077938  0.005698    1.120120
# 50            0.112891  0.017342    0.191659  1.697728  0.007127    1.097443
# 51            0.090483  0.017342    0.153616  1.697728  0.007127    1.074591
# 52            0.112891  0.014556    0.249174  2.207206  0.007961    1.181511
# 53            0.058418  0.014556    0.128940  2.207206  0.007961    1.080962
# 54            0.058504  0.010146    0.089873  1.536191  0.003541    1.034467
# 55            0.112891  0.010146    0.173423  1.536191  0.003541    1.073231

# %% [markdown]
# We can also see several where the confidence is high as well.or instance, we can see that there are quite a few rules with a high lift value which means that it occurs more frequently than would be expected given the number of transaction and product combinations.
# We can filter the dataframe using standard pandas code. In this case, look for a large lift (2) and high confidence (.1):

# %%
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
#positively corelated
rules=rules[ (rules['lift'] >= 2) &
       (rules['confidence'] >= 0.1) ]
rules
# Out:
#                antecedents             consequents  antecedent support  \
# 34           (Large Lemon)                 (Limes)            0.065869
# 35                 (Limes)           (Large Lemon)            0.060080
# 36           (Large Lemon)       (Organic Avocado)            0.065869
# 37       (Organic Avocado)           (Large Lemon)            0.075468
# 46   (Organic Blueberries)  (Organic Strawberries)            0.043024
# 48  (Organic Hass Avocado)   (Organic Raspberries)            0.090483
# 49   (Organic Raspberries)  (Organic Hass Avocado)            0.058418
# 52   (Organic Raspberries)  (Organic Strawberries)            0.058418
# 53  (Organic Strawberries)   (Organic Raspberries)            0.112891
#
#     consequent support   support  confidence      lift  leverage  conviction
# 34            0.060080  0.011879    0.180345  3.001750  0.007922    1.146726
# 35            0.065869  0.011879    0.197723  3.001750  0.007922    1.164349
# 36            0.075468  0.010555    0.160244  2.123337  0.005584    1.100953
# 37            0.065869  0.010555    0.139862  2.123337  0.005584    1.086025
# 46            0.112891  0.010252    0.238274  2.110653  0.005395    1.164604
# 48            0.058418  0.010984    0.121389  2.077938  0.005698    1.071671
# 49            0.090483  0.010984    0.188018  2.077938  0.005698    1.120120
# 52            0.112891  0.014556    0.249174  2.207206  0.007961    1.181511
# 53            0.058418  0.014556    0.128940  2.207206  0.007961    1.080962

# %%
from sklearn.metrics import precision_recall_fscore_support
y_true = np.array(['cat', 'dog', 'pig', 'cat', 'dog', 'pig'])
y_pred = np.array(['cat', 'pig', 'dog', 'cat', 'cat', 'dog'])
precision_recall_fscore_support(y_true, y_pred, average='macro')


precision_recall_fscore_support(y_true, y_pred, average='micro')


precision_recall_fscore_support(y_true, y_pred, average='weighted')
